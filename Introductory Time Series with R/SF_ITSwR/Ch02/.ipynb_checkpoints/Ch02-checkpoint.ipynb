# %% [markdown]
# ##2.2 Exp ectation and the ensemble

# %% [markdown]
# ###2.2.1 Exp ected value

# %%
# www <- "http://www.massey.ac.nz/~pscowper/ts/Herald.dat"
Herald.dat <- read.table('Herald.dat', header = T)
attach (Herald.dat)

# %%
x <- CO; y <- Benzoa; n <- length(x)
sum((x - mean(x))*(y - mean(y))) / (n - 1)
mean((x - mean(x)) * (y - mean(y)))
cov(x, y)
# Out:
# [1] 5.511042
# [1] 5.166602
# [1] 5.511042

# %%
cov(x,y) / (sd(x)*sd(y))
# Out:
# [1] 0.3550973

# %%
cor(x,y)
# Out:
# [1] 0.3550973

# %% [markdown]
# ###2.2.5 Auto correlation

# %%
# www <- "http://www.massey.ac.nz/~pscowper/ts/wave.dat"
wave.dat <- read.table ('wave.dat', header=T) ; attach(wave.dat)
plot(ts(waveht)) ; plot(ts(waveht[1:60]))
# Out:
# Error in replayPlot(obj): invalid graphics state
# plot without title
# Error in replayPlot(obj): invalid graphics state
# plot without title

# %%
acf(waveht)$acf[2]
# Out:
# [1] 0.4702564
# Error in replayPlot(obj): invalid graphics state
# Plot with title "Series  waveht"

# %%
acf(waveht, type = c("covariance"))$acf[2]
# Out:
# [1] 33328.39
# Error in replayPlot(obj): invalid graphics state
# Plot with title "Series  waveht"

# %% [markdown]
# ###2.3.2 Example based on air passenger series

# %%
data(AirPassengers)
AP <- AirPassengers
AP.decom <- decompose(AP, "multiplicative")
plot(ts(AP.decom$random[7:138]))
acf(AP.decom$random[7:138])
# Out:
# Error in replayPlot(obj): invalid graphics state
# plot without title
# Error in replayPlot(obj): invalid graphics state
# Plot with title "Series  AP.decom$random[7:138]"

# %%
sd(AP[7:138])
# Out:
# [1] 109.4187

# %%
 sd(AP[7:138] - AP.decom$trend[7:138])
# Out:
# [1] 41.11491

# %%
sd(AP.decom$random[7:138])
# Out:
# [1] 0.0333884

# %% [markdown]
# ###2.3.3 Example based on the Font Reservoir series

# %%
# www <- "http://www.massey.ac.nz/~pscowper/ts/Fontdsdt.dat"
Fontdsdt.dat <- read.table('Fontdsdt.dat', header=T)
attach(Fontdsdt.dat)
plot(ts(adflow), ylab = ' adflow ' )
acf(adflow, xlab = ' lag (months) ' , main="")
# Out:
# Error in replayPlot(obj): invalid graphics state
# plot without title
# Error in replayPlot(obj): invalid graphics state
# Plot with title ""
